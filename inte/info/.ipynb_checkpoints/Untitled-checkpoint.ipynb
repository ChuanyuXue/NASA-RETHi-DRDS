# %%
import pandas as pd
import numpy as np

# %%
def generate_info(dataid, name, type, subtype, subtype2, rate, size, uint,
                  notes):
    data = {
        name: {
            "data_id": dataid,
            "data_name": name,
            "data_type": type,
            "data_subtype1": subtype,
            "data_subtype2": subtype2,
            "data_rate": rate,
            "data_size": size,
            "data_unit": uint,
            "data_notes": "%d" % notes
        }
    }
    return data

# %%
data = pd.read_csv("Failures Modes in MCVT v6 - Failure Modes of MCVT.csv")

# %%
data.columns
# Out:
# Index(['Status', 'Failure Mode ID', 'Failure Mode Signal In Matlab',
#        'Unnamed: 3', 'Component ID', 'System/Sub-system/Component', 'System',
#        'Component Fault', 'Subsystem', 'Component',
#        'Action Description (For Agent System)', 'ActionID',
#        'Synthetic Observables (Simulink Signal Name)', 'Signal Size',
#        'Categorization of outputs', 'Location', 'Activity Type', 'Location ID',
#        'Data Generation Frequency', 'Data Communication Frequency (Hz)',
#        'Priority (0-7)', 'Worst Case Latency (Sec.)',
#        'Worst Case Data Loss Rate', 'Comments'],
#       dtype='object')

# %%
result = {}

for row in data.iterrows():
    dataid = row['Component ID']
    name = row['System/Sub-system/Component']
    dtype = 1
    subtype = 255
    subtype2 = 255
    rate = 1
    size = int(row['Signal Size'].split('x')[0])
    unit = 'n/a'
    notes =
# Out:
#      Status Failure Mode ID  Failure Mode Signal In Matlab  Unnamed: 3  \
# 0       NaN       5.001.001                        5001001           1
# 1       NaN       5.001.002                        5001002           2
# 2       NaN       5.002.001                        5002001           3
# 3       NaN       5.002.002                        5002002           4
# 4       NaN       5.002.003                        5002003           5
# ..      ...             ...                            ...         ...
# 112     NaN       3.013.002                        3013002         113
# 113     NaN       3.013.003                        3013003         114
# 114     NaN       3.014.001                        3014001         115
# 115     NaN       3.014.002                        3014002         116
# 116     NaN       3.014.003                        3014003         117
#
#      Component ID           System/Sub-system/Component System  \
# 0            5001  ECLSS/ECLSS Exterior/Radiator Panels  ECLSS
# 1            5001  ECLSS/ECLSS_Exterior/Radiator_Panels  ECLSS
# 2            5002              ECLSS/ECLSS_Pressure/Fan  ECLSS
# 3            5002         ECLSS/ECLSS_Pressure/Air_Tank  ECLSS
# 4            5002     ECLSS/ECLSS_Pressure/Supply_Valve  ECLSS
# ..            ...                                   ...    ...
# 112          3013     Power/Power_Storage/Power_Meter_1  Power
# 113          3013     Power/Power_Storage/Power_Meter_1  Power
# 114          3014            Power/Power_Storage/Temp_1  Power
# 115          3014            Power/Power_Storage/Temp_1  Power
# 116          3014            Power/Power_Storage/Temp_1  Power
#
#                                 Component Fault       Subsystem  \
# 0                             Dust Accumulation  ECLSS_Exterior
# 1                             Paint Degradation  ECLSS_Exterior
# 2                          Fan's filter failure  ECLSS_Pressure
# 3                                     Tank leak  ECLSS_Pressure
# 4                             Malfunction/Stuck  ECLSS_Pressure
# ..                                          ...             ...
# 112             Sensor Failure requiring repair   Power Storage
# 113  Sensor Drift/Failing requiring replacement   Power Storage
# 114       Sensor Drift Failure requiring repair   Power Storage
# 115             Sensor Failure requiring repair   Power Storage
# 116  Sensor Drift/Failing requiring replacement   Power Storage
#
#                Component  ...             Categorization of outputs  \
# 0        Radiator Panels  ...      Binary value for each subsection
# 1        Radiator Panels  ...      Binary value for each subsection
# 2                    Fan  ...          Binary (0:Healthy or 1:Fail)
# 3               Air Tank  ...  Categorical 1~4 (Healthy ~ Max Fail)
# 4           Supply Valve  ...  Categorical 1~4 (Healthy ~ Max Fail)
# ..                   ...  ...                                   ...
# 112        Power Meter 1  ...                                   NaN
# 113        Power Meter 1  ...                                   NaN
# 114  Temperature Meter 1  ...                                   NaN
# 115  Temperature Meter 1  ...                                   NaN
# 116  Temperature Meter 1  ...                                   NaN
#
#            Location Activity Type Location ID Data Generation Frequency  \
# 0    ECLSS_Radiator             1           3           1/dt_5 (200 Hz)
# 1    ECLSS_Radiator             1           3           1/dt_5 (200 Hz)
# 2              Dome             1           2           1/dt_5 (200 Hz)
# 3              Dome             1           2           1/dt_5 (200 Hz)
# 4              Dome             1           2           1/dt_5 (200 Hz)
# ..              ...           ...         ...                       ...
# 112           Dome              3           2                       NaN
# 113           Dome              3           2                       NaN
# 114           Dome              3           2                       NaN
# 115           Dome              3           2                       NaN
# 116           Dome              3           2                       NaN
#
#     Data Communication Frequency (Hz)  Priority (0-7)  \
# 0                                 1.0             1.0
# 1                                 1.0             1.0
# 2                                 1.0             1.0
# 3                                 1.0             1.0
# 4                                 1.0             NaN
# ..                                ...             ...
# 112                               NaN             NaN
# 113                               NaN             NaN
# 114                               NaN             NaN
# 115                               NaN             NaN
# 116                               NaN             NaN
#
#      Worst Case Latency (Sec.) Worst Case Data Loss Rate  Comments
# 0                          1.0                      0.01       NaN
# 1                          1.0                      0.01       NaN
# 2                          1.0                      0.01       NaN
# 3                          1.0                      0.01       NaN
# 4                          NaN                       NaN       NaN
# ..                         ...                       ...       ...
# 112                        NaN                       NaN       NaN
# 113                        NaN                       NaN       NaN
# 114                        NaN                       NaN       NaN
# 115                        NaN                       NaN       NaN
# 116                        NaN                       NaN       NaN
#
# [117 rows x 24 columns]
